# %% [markdown]
# <a href="https://colab.research.google.com/github/yadsan/aiml1/blob/main/Assignment2_DFS_BFS.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <b>The Problem Statement</b>:
#
# Implement Breadth-First Search (BFS) and Depth-First Search (DFS) algorithms in Python to analyze a simple social network. The program aims to explore social connections between users and offer insights into their relationships
#
#
#
# <b>Question 1:</b>
# <p>Write a function which takes 3 parameter:</p>
# <p>1- graph</p>
# <p>2- source_node</p>
# <p>3- desination_node</p>
# Return the path between “source_node” and “desination_node” using BFS.
#
# <b>Question 2:</b>
# <p>Write a function which takes 3 parameter:</p>
# <p>1- graph</p>
# <p>2- source_node</p>
# <p>3- desination_node</p>
# Return the path between “source_node” and “desination_node” using DFS.

# %% [markdown]
# ![Picture1.png](data:image/png;base64,...)

# %% [markdown]
# ## The Code

# %% [markdown]
# ### Imports Needed

# %%
from collections import defaultdict, deque

# %% [markdown]
# ### Define the graph using adjacency list

# %%
graph = {
    "Bob": ["Bill", "Brenda", "Sally"],

    # fill the rest of the elements
}

# %%
def path_using_bfs(graph, source_node, destination_node):
  #TODO Complete the function definition

# %%
def path_using_dfs(graph, source_node, destination_node):
  #TODO Complete the function definition
